# %% [markdown]
#                                                Theoretical Questions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
# - Function: Independent block of code that can be called anywhere.
# - Method: Associated with an object and has access to the data within it.
#      Example:
#        def greet():
#           print("Hello!")
#        class Greeter:
#           def greet(self):
#         print("Hello!")

# %% [markdown]
# 2. Explain the concept of Function Arguments and Parameters in Python.
#  - Parameters: Variables in the function definition.
#  - Arguments: Actual values passed during a function call.

# %%
      def add(a, b):
        return a + b
      add(2, 3)
# Out:
# 5

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
# - Functions can be defined using def or lambda. Calling involves writing the function name followed by parentheses.
#    Example:

# %%
def greet():
   print("Hi")
greet()
hello = greet
hello()
# Out:
# Hi
# Hi

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#   - The `return` statement is used to send a value back to the caller from a function.
#      Example:
#      def square(x): return x * x
#
# 5. What are iterators in Python and how do they differ from iterables?
#   - Iterables are objects that can return an iterator, while iterators are
#     objects representing a stream of data.
#       Example:
#       Iterable: [1, 2, 3]
#       Iterator: iter([1, 2, 3])
#
# 6. Explain the concept of generators in Python and how they are defined
#   - Generators are functions that yield values using the `yield` keyword
#     instead of `return`.They produce items one at a time.
#       Example

# %%
def gen(): yield 1; yield 2

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
# - Generators are memory efficient, as they generate values lazily. They are
#   suitable for large data processing.
# 8. What is a lambda function in Python and when is it typically used?
# - A lambda function is an anonymous function defined with the `lambda` keyword.
#     Example:

# %%
square = lambda x: x * x
result=square(5)
print(result)
# Out:
# 25

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
# - The `map()` function applies a function to all items in an iterable.
#     Example:

# %%
list(map(lambda x: x**2, [1, 2, 3]))
# Out:
# [1, 4, 9]

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# - `map()`: Applies a function to every item.
# - `reduce()`: combines items using a function(from functools).
# - `filter()`: Selects elements based on a condition.

# %%
from functools import reduce  # Import reduce from functools

map: map(str.upper, ['a', 'b'])
reduce: reduce(lambda x, y: x + y, [1, 2, 3])  # Now reduce is defined
filter: filter(lambda x: x > 2, [1, 2, 3])

# %% [markdown]
# 11. Using pen & paper, write the internal mechanism for sum operation using reduce function on the
# list [47, 11, 42, 13]:

# %% [markdown]
# ![WhatsApp Image 2025-04-30 at 15.52.36.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
#
#                                                               Practical Q/A

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_of_evens(numbers):
 return sum(num for num in numbers if num % 2 == 0)

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
 return s[::-1]

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_list(numbers):
 return [num**2 for num in numbers]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2:
        return False  # Numbers less than 2 are not prime
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False  # If divisible by any number in the range, it's not prime
    return True  # If not divisible by any number in the range, it's prime

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified
# number of terms.

# %%
class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        # The line after the method definition needs to be indented
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        fib = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return fib

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exp):
   for i in range(exp + 1):
       yield 2 ** i

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
   with open(file_path, 'r') as file:
     for line in file:
        yield line.strip()

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
tuples = [(1, 3), (4, 1), (2, 2)]
sorted_tuples = sorted(tuples, key=lambda x: x[1])

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 10, 20, 30]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

# %%
[32.0, 50.0, 68.0, 86.0]
# Out:
# [32.0, 50.0, 68.0, 86.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(s):
 vowels = 'aeiouAEIOU'
 return ''.join(filter(lambda x: x not in vowels, s))

# %%
string_with_vowels = "Hello, world!"
string_without_vowels = remove_vowels(string_with_vowels)
print(string_without_vowels)  # Output: Hll, wrld!
# Out:
# Hll, wrld!

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#   Order number   Book Title and Author           Quantity     Price per item
#   34587         Learning Python, Mark Lutz          4          40.95
#   98762         Programming Python,Mark Lutz        5          56.80
#   77226         Head First Python, Paul Barry       3          32.95
#   88112         Einfuhrung inPython3,Bernd Klein    3          24.99
#
#   Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
#   order is smaller than 100,00 €.
#
#   Write a Python program using lambda and map.

# %%
Book_shop = [
    [34587, 'Learning Python, Mark Lutz', 4, 40.95],
    [98762, 'Programming Python, Mark Lutz', 5, 56.80],
    [77226, 'Head First Python, Paul Barry', 3, 32.95],
    [88112, 'Einführung in Python3, Bernd Klein', 3, 24.99]
]  # Removed extra ']' and corrected indentation
final_list = list(map(lambda order: (order[0], order[2] * order[3] + 10 if (order[2] * order[3]) < 100 else order[2] * order[3]), Book_shop)) # Changed book_shop to Book_shop to match the variable name

print(final_list)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
